# %%
import pandas as pd
import plotly_express as px

# %%
df = pd.read_csv('../data/kaasa/kaasa_altitude_2019.csv')
df = df.astype({"individual": str})
print(df.head(5))
# Out:
#    source_id individual  owner_id            name            date_time  \
# 0      87457      97400     32957  Oddbjørn Kaasa  2015-06-12 17:22:55
# 1      87457      97400     32957  Oddbjørn Kaasa  2015-06-12 17:27:32
# 2      87457      97400     32957  Oddbjørn Kaasa  2015-06-12 17:32:26
# 3      87457      97400     32957  Oddbjørn Kaasa  2015-06-12 17:37:32
# 4      87457      97400     32957  Oddbjørn Kaasa  2015-06-12 17:42:32
#
#    longitude   latitude  velocity  distance  temperature  altitude
# 0  11.716970  63.402163     0.000     0.000          7.1    184.60
# 1  11.716967  63.402105    12.977     6.489          7.1    184.70
# 2  11.716915  63.402157    12.589     6.295          7.1    184.68
# 3  11.716830  63.402215    15.489     7.745          7.1    184.50
# 4  11.716938  63.402190    12.135     6.068          7.1    184.35

# %% [markdown]
# # Altitude

# %%
px.scatter(df, x='date_time', y='altitude', color='individual')
