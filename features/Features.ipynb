# %%
import pandas as pd
import plotly_express as px

# %%
df = pd.read_csv('../data/kaasa/kaasa_2021.csv')
df = df.astype({"individual": str})
print(df.head(5))
# Out:
#    source_id individual  owner_id            name            date_time  \
# 0      87457      97400     32957  Oddbjørn Kaasa  2019-06-04 12:28:31
# 1      87457      97400     32957  Oddbjørn Kaasa  2019-06-04 12:33:36
# 2      87457      97400     32957  Oddbjørn Kaasa  2019-06-04 12:38:36
# 3      87457      97400     32957  Oddbjørn Kaasa  2019-06-04 12:43:35
# 4      87457      97400     32957  Oddbjørn Kaasa  2019-06-05 00:48:37
#
#    longitude   latitude  velocity  distance  temperature  altitude
# 0  11.716902  63.402090     0.000     0.000         11.8    185.04
# 1  11.716683  63.402153    25.903    12.952         11.8    184.56
# 2  11.716563  63.402023    31.282    15.641         11.8    185.18
# 3  11.716933  63.402027    36.848    18.424         11.8    184.83
# 4  11.715733  63.401928   121.469    60.735          9.5    183.99

# %% [markdown]
# # Altitude

# %%
px.scatter(df, x='date_time', y='altitude', color='individual')
